# %%
#Day 4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from numpy import array

# %%
from pandas import read_csv

# %%
df = pd.read_csv('weight-height.csv')

# %%
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
plt.scatter(df["Height"],df["Weight"])

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(df[["Height"]],df["Weight"]) #fit is used to train the model
# Out:
# LinearRegression()

# %%
slope = model.coef_

# %%
intercept = model.intercept_

# %%
print(slope)
print(intercept)
# Out:
# [7.71728764]
# -350.73719181213676

# %%
model.predict([[70]])
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([189.47294304])

# %%
plt.plot(df["Height"], slope*df["Height"] +intercept, c = "black")
plt.scatter(df['Height'] , df["Weight"])
plt.xlabel("Height")
plt.ylabel("Weight")
# Out:
# Text(0, 0.5, 'Weight')

# %%
df1 = pd.read_csv("homeprices.csv")

# %%
df1
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
plt.scatter(df["area"],df["price"])

# %%
model1 = LinearRegression()
model1.fit(df[["area"]],df["price"])
# Out:
# LinearRegression()

# %%
slope = model1.coef_

# %%
intercept = model1.intercept_

# %%
print(slope)
print(intercept)
# Out:
# [118.29495955]
# 257056.62725575588

# %%
model.predict([[2020]])
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([15238.18384257])

# %%
plt.plot(df["area"], slope*df["area"] +intercept, c = "yellow")
plt.scatter(df['area'] , df["price"])
plt.xlabel("Area")
plt.ylabel("Prices")
# Out:
# Text(0, 0.5, 'Prices')
